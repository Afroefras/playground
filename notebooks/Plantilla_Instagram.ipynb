# %% [markdown]
# # Plantilla para post de Instagram

# %%
IMAGE_NAME = '2021_09_collage.png'

# %%
import sys
sys.path.append('/content/drive/MyDrive/Colab Notebooks')

# %%
from Betterware import Instagram

ig = Instagram('/content/drive/MyDrive/wallpaper', IMAGE_NAME)
#pre_post = ig.set_canvas(bright=0.9, blur=8, resize_to=1.1, margin=0.15, add_original=True, just_color=False, save=True, png=True)
pre_post = ig.set_canvas(bright=1, blur=0, resize_to=1, margin=0, add_original=True, just_color=False, save=False)
display(pre_post.resize((int(x*.1) for x in pre_post.size)))
# Out:
# <PIL.Image.Image image mode=RGBA size=324x324 at 0x7FBE7B591CD0>

# %%
grid_imgs = ig.split_img(pre_post, save_grid=True, png=False)

# %%
# PARA BORRAR LA CARPETA JUNTO CON TODAS LAS IMÁGENES DENTRO
# import shutil
# shutil.rmtree(f'/content/drive/MyDrive/wallpaper/{"".join(IMAGE_NAME.split(".")[:-1])}_grid')
